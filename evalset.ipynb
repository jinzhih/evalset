# %%
import matplotlib.pyplot as plt
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import pandas_profiling

# %%
order_products = pd.read_csv('data/order_products.csv')

# %%
order_products.head()
# Out:
#    order_id  product_id  add_to_cart_order
# 0         2       33120                  1
# 1         2       28985                  2
# 2         2        9327                  3
# 3         2       45918                  4
# 4         2       30035                  5

# %%
orders = pd.read_csv('data/orders.csv')

# %%
orders.head()
# Out:
#    order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1             1          2                  8
# 1   2398795        1             2          3                  7
# 2    473747        1             3          3                 12
# 3   2254736        1             4          4                  7
# 4    431534        1             5          4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %%
order_products.shape
# Out:
# (33819106, 3)

# %%
orders.shape
# Out:
# (3421083, 6)

# %%
order_products.order_id.nunique()
# Out:
# 3346083

# %%
orders.order_id.nunique()
# Out:
# 3421083

# %%
data = pd.merge(orders, order_products, on = "order_id",  how = "left")
data
# Out:
#           order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0          2539329        1             1          2                  8
# 1          2539329        1             1          2                  8
# 2          2539329        1             1          2                  8
# 3          2539329        1             1          2                  8
# 4          2539329        1             1          2                  8
# ...            ...      ...           ...        ...                ...
# 33894101    272231   206209            14          6                 14
# 33894102    272231   206209            14          6                 14
# 33894103    272231   206209            14          6                 14
# 33894104    272231   206209            14          6                 14
# 33894105    272231   206209            14          6                 14
#
#           days_since_prior_order  product_id  add_to_cart_order
# ...

# %%
data[data['product_id'].isnull()]

# %%
test=data[data['product_id'].isnull()]

# %%
test['eval_set']='Test'
test
# Out:
# /Users/jinhou/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#           order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 384        2774568        3            13          5                 15
# 403         329954        4             6          3                 12
# 464        1528013        6             4          3                 16
# 1086       1376945       11             8          6                 11
# 1161       1356845       12             6          1                 20
# ...            ...      ...           ...        ...                ...
# ...

# %%
order_new_test=test.iloc[:,[0,1,2,3,4,5,8]]
order_new_test
# Out:
#           order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 384        2774568        3            13          5                 15
# 403         329954        4             6          3                 12
# 464        1528013        6             4          3                 16
# 1086       1376945       11             8          6                 11
# 1161       1356845       12             6          1                 20
# ...            ...      ...           ...        ...                ...
# 33892542   2728930   206202            23          2                 17
# 33892729    350108   206204             5          4                 14
# 33893066   1043943   206206            68          0                 20
# 33893290   2821651   206207            17          2                 13
# 33893968    803273   206208            50          5                 11
#
#           days_since_prior_order eval_set
# 384                         11.0     Test
# ...

# %%
lables = data[data['product_id'].isnull()].index.tolist()
len(lables)
# Out:
# 75000

# %%
grouped=orders.groupby(['user_id'])["order_id"].aggregate("max").reset_index()
grouped
# Out:
#         user_id  order_id
# 0             1   3367565
# 1             2   3268552
# 2             3   3225766
# 3             4   3343014
# 4             5   2717275
# ...         ...       ...
# 206204   206205   2658896
# 206205   206206   3394383
# 206206   206207   3316103
# 206207   206208   3412250
# 206208   206209   3186442
#
# [206209 rows x 2 columns]

# %%
prior=orders[~orders['order_id'].isin(latest_order_list)]
#data_2=data_1[~(data_1.E.isin(["a"])&data_1.F.isin(["d","f"]))]
prior
# Out:
#          order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0         2539329        1             1          2                  8
# 1         2398795        1             2          3                  7
# 2          473747        1             3          3                 12
# 3         2254736        1             4          4                  7
# 4          431534        1             5          4                 15
# ...           ...      ...           ...        ...                ...
# 3421078   2266710   206209            10          5                 18
# 3421079   1854736   206209            11          4                 10
# 3421080    626363   206209            12          1                 12
# 3421081   2977660   206209            13          1                 12
# 3421082    272231   206209            14          6                 14
#
#          days_since_prior_order
# 0                           NaN
# 1                          15.0
# ...

# %%
prior_list=prior['order_id'].tolist()
len(prior_list)
# Out:
# 3214874

# %%
order_new_prior = prior
order_new_prior['eval_set']='Prior'
order_new_prior
# Out:
# /Users/jinhou/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#          order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0         2539329        1             1          2                  8
# 1         2398795        1             2          3                  7
# 2          473747        1             3          3                 12
# 3         2254736        1             4          4                  7
# 4          431534        1             5          4                 15
# ...           ...      ...           ...        ...                ...
# 3421078   2266710   206209            10          5                 18
# ...

# %%
train = pd.merge(latest_order1, order_products, on = "order_id",  how = "outer")
train1 = pd.merge(latest_order1, order_products, on = "order_id",  how = "inner")

# %%
data4 = train[train['product_id'].isnull()].order_id.unique()
len(data4)
# Out:
# 8405

# %%
test=orders[orders['order_id'].isin(data4)]
#data_2=data_1[~(data_1.E.isin(["a"])&data_1.F.isin(["d","f"]))]
test
# Out:
#          order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 475       3202221       32             6          1                 13
# 479       3222866       33             4          6                 17
# 632       2827745       45             5          5                 10
# 750       2174416       51             4          0                 14
# 1059      2817181       69             6          2                 11
# ...           ...      ...           ...        ...                ...
# 3419370   3288037   206103            29          6                  8
# 3419710   3317783   206120             8          0                  9
# 3419911   2964171   206131            13          1                 15
# 3420334   1722401   206163             6          5                 21
# 3420440   3151043   206173             4          0                 13
#
#          days_since_prior_order
# 475                        30.0
# 479                        19.0
# ...

# %%
order_new_test = test
order_new_test
# Out:
#          order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 475       3202221       32             6          1                 13
# 479       3222866       33             4          6                 17
# 632       2827745       45             5          5                 10
# 750       2174416       51             4          0                 14
# 1059      2817181       69             6          2                 11
# ...           ...      ...           ...        ...                ...
# 3419370   3288037   206103            29          6                  8
# 3419710   3317783   206120             8          0                  9
# 3419911   2964171   206131            13          1                 15
# 3420334   1722401   206163             6          5                 21
# 3420440   3151043   206173             4          0                 13
#
#          days_since_prior_order
# 475                        30.0
# 479                        19.0
# ...

# %%
order_new_test['eval_set']='Test'
order_new_test
# Out:
# /Users/jinhou/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#          order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 475       3202221       32             6          1                 13
# 479       3222866       33             4          6                 17
# 632       2827745       45             5          5                 10
# 750       2174416       51             4          0                 14
# 1059      2817181       69             6          2                 11
# ...           ...      ...           ...        ...                ...
# ...

# %%
data5 = train1.order_id.unique()
len(data5)
# Out:
# 197804

# %%
train=orders[orders['order_id'].isin(data5)]
#data_2=data_1[~(data_1.E.isin(["a"])&data_1.F.isin(["d","f"]))]
train
# Out:
#          order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 5         3367565        1             6          2                  7
# 23        3268552        2            13          4                 11
# 33        3225766        3             8          0                 17
# 39        3343014        4             1          6                 11
# 45        2717275        5             1          3                 12
# ...           ...      ...           ...        ...                ...
# 3420931   2658896   206205             2          2                 15
# 3420977   3394383   206206            44          6                 18
# 3421012   3316103   206207            11          1                  7
# 3421047   3412250   206208            29          4                 18
# 3421074   3186442   206209             6          0                 16
#
#          days_since_prior_order
# 5                          19.0
# 23                         30.0
# ...

# %%
order_new_train = train
order_new_train
# Out:
#          order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 5         3367565        1             6          2                  7
# 23        3268552        2            13          4                 11
# 33        3225766        3             8          0                 17
# 39        3343014        4             1          6                 11
# 45        2717275        5             1          3                 12
# ...           ...      ...           ...        ...                ...
# 3420931   2658896   206205             2          2                 15
# 3420977   3394383   206206            44          6                 18
# 3421012   3316103   206207            11          1                  7
# 3421047   3412250   206208            29          4                 18
# 3421074   3186442   206209             6          0                 16
#
#          days_since_prior_order
# 5                          19.0
# 23                         30.0
# ...

# %%
order_new_train['eval_set']='Train'
# Out:
# /Users/jinhou/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
order_new_train
# Out:
#          order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 5         3367565        1             6          2                  7
# 23        3268552        2            13          4                 11
# 33        3225766        3             8          0                 17
# 39        3343014        4             1          6                 11
# 45        2717275        5             1          3                 12
# ...           ...      ...           ...        ...                ...
# 3420931   2658896   206205             2          2                 15
# 3420977   3394383   206206            44          6                 18
# 3421012   3316103   206207            11          1                  7
# 3421047   3412250   206208            29          4                 18
# 3421074   3186442   206209             6          0                 16
#
#          days_since_prior_order eval_set
# 5                          19.0    Train
# ...

# %%
frames = [order_new_test, order_new_prior, order_new_train]
order_new = pd.concat(frames)
order_new
# Out:
#          order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 475       3202221       32             6          1                 13
# 479       3222866       33             4          6                 17
# 632       2827745       45             5          5                 10
# 750       2174416       51             4          0                 14
# 1059      2817181       69             6          2                 11
# ...           ...      ...           ...        ...                ...
# 3420931   2658896   206205             2          2                 15
# 3420977   3394383   206206            44          6                 18
# 3421012   3316103   206207            11          1                  7
# 3421047   3412250   206208            29          4                 18
# 3421074   3186442   206209             6          0                 16
#
#          days_since_prior_order eval_set
# 475                        30.0     Test
# ...

# %%
lables
# Out:
# [384,
#  403,
#  464,
#  1086,
#  1161,
#  1541,
#  1612,
#  2167,
#  2190,
#  2471,
#  2584,
#  2641,
#  3610,
#  4164,
#  4279,
#  4333,
#  4555,
#  4709,
#  5265,
#  5370,
#  5832,
#  6695,
#  7543,
#  7870,
#  7968,
#  8149,
#  8237,
#  9327,
#  9378,
#  10019,
#  10384,
#  10623,
#  11226,
#  12901,
#  12997,
#  13419,
#  13673,
#  13844,
#  14234,
#  15745,
#  16214,
#  16520,
#  16686,
#  17466,
#  17514,
#  17600,
#  17673,
#  19055,
#  20572,
#  21027,
#  21724,
#  21992,
#  22613,
#  22876,
#  22960,
#  23014,
#  23667,
#  24046,
#  24075,
#  24288,
#  24393,
#  24484,
#  25323,
#  25645,
#  25742,
#  25947,
#  26325,
#  26612,
#  26837,
#  27048,
#  27243,
#  27973,
#  28395,
#  29208,
#  32218,
#  33103,
#  34331,
#  35128,
#  35179,
#  35978,
#  36457,
#  37008,
#  37729,
#  37799,
#  38256,
#  38802,
#  38894,
#  38926,
#  39319,
#  39559,
#  39758,
#  40199,
#  40922,
#  41666,
#  41697,
#  42104,
#  42172,
#  42643,
#  42807,
#  42870,
#  42894,
#  43263,
#  44108,
# ...

# %%
len(latest_order_list)
# Out:
# 206209

# %%
total = orders['order_id'].unique()
len(total)
# Out:
# 3421083

# %%
noprior = list(set(total).difference(set(prior_list)))
len(noprior)
# Out:
# 206209

# %%
trainlist = list(set(noprior).difference(set(lables))).unique()
len(trainlist)
# Out:
# 205761

# %%
len(lables)
# Out:
# 75000

# %%
len(order_new_test['order_id'].unique())
# Out:
# 75000

# %%
len(prior['order_id'].unique())
# Out:
# 3214874

# %%
train=orders[orders['order_id'].isin(orders['order_id'].unique())&~orders['order_id'].isin(order_new_test['order_id'].unique())&~orders['order_id'].isin(prior['order_id'].unique())]
#data_2=data_1[~(data_1.E.isin(["a"])&data_1.F.isin(["d","f"]))]
train
# Out:
#          order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 5         3367565        1             6          2                  7
# 23        3268552        2            13          4                 11
# 33        3225766        3             8          0                 17
# 39        3343014        4             1          6                 11
# 45        2717275        5             1          3                 12
# ...           ...      ...           ...        ...                ...
# 3420931   2658896   206205             2          2                 15
# 3420977   3394383   206206            44          6                 18
# 3421012   3316103   206207            11          1                  7
# 3421047   3412250   206208            29          4                 18
# 3421074   3186442   206209             6          0                 16
#
#          days_since_prior_order
# 5                          19.0
# 23                         30.0
# ...

# %%
len(train['order_id'].unique())
# Out:
# 197804
